# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv .
# Out:
# --2024-10-14 06:56:02--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  43.19K   286KB/s    in 0.2s
#
# 2024-10-14 06:56:03 (286 KB/s) - ‘titanic.csv’ saved [44225/44225]
#
# --2024-10-14 06:56:03--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2024-10-14 06:56:03--
# Total wall clock time: 0.5s
# Downloaded: 1 files, 43K in 0.2s (286 KB/s)

# %% [markdown]
# ## Задание 1
# Прочитайте файл в датафрейм, так, чтобы появились корректные колонки без каких-либо дополнительных действий, и отобразите первые 5 строчек

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# ## Задание 2
# Вывести имена всех выживших детей и их количество (у детей возраст < 18)

# %%
children_survived = df[(df['Age'] < 18) & (df['Survived'] == 1)]
children_survived_names = children_survived['Name']
children_survived_count = children_survived.shape[0]

# %%
print(children_survived_names)
print("Количество выживших детей:", children_survived_count)
# Out:
# 9           Mrs. Nicholas (Adele Achem) Nasser
# 10              Miss. Marguerite Rut Sandstrom
# 22                          Miss. Anna McGowan
# 39                  Miss. Jamila Nicola-Yarred
# 42     Miss. Simonne Marie Anne Andree Laroche
#                         ...
# 826     Mrs. Antoni (Selini Alexander) Yasbeck
# 827             Master. George Sibley Richards
# 849                   Miss. Mary Conover Lines
# 865             Master. Harold Theodor Johnson
# 871                   Miss. Adele Kiamie Najib
# Name: Name, Length: 65, dtype: object
# Количество выживших детей: 65

# %% [markdown]
# ## Задание 3
# Сделайте индексом колонку Name

# %%
df.set_index("Name", inplace = True)
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mr. Owen Harris Braund                                     0       3    male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1  female
# Miss. Laina Heikkinen                                      1       3  female
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1       1  female
# Mr. William Henry Allen                                    0       3    male
#
#                                                      Age  \
# Name
# Mr. Owen Harris Braund                              22.0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  38.0
# Miss. Laina Heikkinen                               26.0
# Mrs. Jacques Heath (Lily May Peel) Futrelle         35.0
# Mr. William Henry Allen                             35.0
#
#                                                     Siblings/Spouses Aboard  \
# Name
# ...

# %% [markdown]
# ## Задание 4
# Выведите возраст, и колонку Survived всех людей у которых в имени есть слово Henry

# %%
henry_pepole = df[df.index.str.contains("Henry")]
henry_pepole[["Age", "Survived"]]
# Out:
#                                                     Age  Survived
# Name
# Mr. William Henry Allen                            35.0         0
# Mr. William Henry Saundercock                      20.0         0
# Mrs. Henry Sleeper (Myna Haxtun) Harper            49.0         1
# Mr. Henry Birkhardt Harris                         45.0         0
# Master. Thomas Henry Sage                           5.0         0
# Master. Henry Forbes Lefebre                        5.0         0
# Mr. Henry Blank                                    40.0         1
# Mr. John Henry Perkin                              22.0         0
# Mr. George Henry Green                             51.0         0
# Mrs. Henry Birkhardt (Irene Wallach) Harris        35.0         1
# Mr. George Henry Hunt                              33.0         0
# Miss. Delia Henry                                  21.0         0
# Mr. William Henry Tornquist                        25.0         1
# ...

# %% [markdown]
# ## Задание 5
# Посчитайте среднюю выживаемость в зависимости от приставки в имени.
#
# *Подсказка: приставка -- первое слово, или то слово, которое обозначается через точку (см результат для Henry). Воспользуйтесь groupby и строковыми методами работы .str*

# %%
df.groupby(df.index.str.split(".").str[0])["Survived"].mean()
# Out:
# Name
# Capt            0.000000
# Col             0.500000
# Don             0.000000
# Dr              0.428571
# Jonkheer        0.000000
# Lady            1.000000
# Major           0.500000
# Master          0.575000
# Miss            0.697802
# Mlle            1.000000
# Mme             1.000000
# Mr              0.157895
# Mrs             0.792000
# Ms              1.000000
# Rev             0.000000
# Sir             1.000000
# the Countess    1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# ## Задание 6
# Постройте гистограмму по признаку Survived

# %%
plt.hist(df['Survived'], bins=2, edgecolor = "black")
plt.title('Распределение признака Survived')
plt.xlabel('Выживание (0 - не выжил, 1 - выжил)')
plt.ylabel('Количество')
plt.xticks([0, 1])
plt.show()

# %% [markdown]
# ## Задание 7
# С помощью pairplot постройте попарные графики с раскраской по полю Survived.

# %%
sns.pairplot(df, hue = "Survived")
plt.show()

# %% [markdown]
# ## Задание 8
# Точки накладываются друг на друга, не очень понятно что происходит, найдите способ отобразить точки с параметром прозрачности и снова постройте pairplot.
#
# *Подсказка: гугл.*

# %%
sns.pairplot(df, hue='Survived', plot_kws={'alpha':0.3})
plt.show()

# %% [markdown]
# ## Задание 9
# Теперь мы лучше видим концентрацию точек, давайте посмотрим более детально на разрез возраст/класс/пол пассажира.
#
# Сделайте FacetGrid в разбиении по Pclass.
#
# Вы можете найти полезным вот [этот материал](https://nagornyy.me/it/vizualizatsiia-dannykh-v-seaborn/#facet-grid)

# %%
g = sns.FacetGrid(df, col='Pclass', row='Sex', height=4, aspect=1.2)
g.map_dataframe(sns.histplot, x='Age', kde=False, bins=20, color='c', alpha=0.6)
g.add_legend()
plt.show()

# %% [markdown]
# ## Задание 10
# Постройте еще какой-нибудь интересный по вашему мнению график, приведенный в материале выше. Объясните почему вы построили именно его.

# %%
grid = sns.FacetGrid(df, col = "Survived", row = "Sex", height = 4, aspect = 1.2)
grid.map_dataframe(sns.histplot, x = "Age", kde = False, bins = 20, color='c', alpha = 0.6)

plt.show()

# %% [markdown]
# ## Задание 11
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя groupby + unstack

# %%
pivot_table = df.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()
print(pivot_table)
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.137026

# %% [markdown]
# ## Задание 12
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя метод pivot_table

# %%
pivot_table = pd.pivot_table(df, values = 'Survived', index = 'Pclass', columns = 'Sex', aggfunc = 'mean')
print(pivot_table)
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.137026

# %% [markdown]
# ## Задание 13
# Попробуйте найти еще какой-нибудь фактор выживаемости с помощью доступных вам сейчас методов.
#
# Т.е, используя выборки, аггрегацию, графики

# %%
# Был выбран фактор выживаемости в зависимости от возраста
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Survived'] == 0]['Age'].dropna(), bins=30, kde=False, label='no survive', color='red')
sns.histplot(df[df['Survived'] == 1]['Age'].dropna(), bins=30, kde=False, label='Survived', color='green')

plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
